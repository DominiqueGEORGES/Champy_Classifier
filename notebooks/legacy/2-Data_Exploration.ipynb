# %% [markdown]
# Exploration du Dataset final "observations_mushroom.csv" + "champignons_france_top30.csv"

# %%
"""
Les précédentes data explorations nous permettent de constituer le dataset final pour nos futurs modèles.

Celui-ci cible le top 30 des espèces les plus courantes en France.

Il est constitué de la fusion du dataset "champignons_france_top30.csv" et de notre dataset initial "observations_mushroom.csv" (filtré avec l'indice de confiance >= 92%)

"""
# Out:
# '\nLes précédentes data explorations nous permettent de constituer le dataset final pour nos futurs modèles.\n\nCelui-ci cible le top 30 des espèces les plus courantes en France.\n\nIl est constitué de la fusion du dataset "champignons_france_top30.csv" et de notre dataset initial "observations_mushroom.csv" (filtré avec l\'indice de confiance >= 92%)\n\n'

# %%
# import des librairies nécessaires

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Chemins d'accès

rep_data = "C:\\Users\\Utilisateur\\Documents\\Projet_MLOps\\Champy_Classifier\\data\\"  # Chemin vers les datasets csv + images raw => processed => split

# %%
# lecture du fichier 'observations_mushroom.csv'

df = pd.read_csv(rep_data + "dataset_30_species.csv", sep=",")

display(df.head(5))
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\2433113407.py:3: DtypeWarning: Columns (2,5,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(rep_data+'dataset_30_species.csv', sep =  ",")
#   image_lien  image_id observation                  label  \
# 0     66.jpg        66          55    Trametes versicolor
# 1     67.jpg        67          56    Trametes versicolor
# 2     68.jpg        68          56    Trametes versicolor
# 3    100.jpg       100          86  Schizophyllum commune
# 4    107.jpg       107          93      Russula virescens
#
#                                     image_url user                 date  \
# 0   http://mushroomobserver.org/images/320/66    1  2006-05-21 07:18:39
# 1   http://mushroomobserver.org/images/320/67    1  2006-05-21 07:18:40
# 2   http://mushroomobserver.org/images/320/68    1  2006-05-21 07:18:40
# 3  http://mushroomobserver.org/images/320/100    1  2006-05-21 07:19:29
# 4  http://mushroomobserver.org/images/320/107    1  2006-05-21 07:19:38
#
#   gbif_info/kingdom  gbif_info/family  gbif_info/speciesKey  ...  \
# 0             Fungi      Polyporaceae             2548311.0  ...
# 1             Fungi      Polyporaceae             2548311.0  ...
# 2             Fungi      Polyporaceae             2548311.0  ...
# 3             Fungi  Schizophyllaceae             5241128.0  ...
# 4             Fungi       Russulaceae             2551423.0  ...
#
#   gbif_info/genus gbif_info/order  thumbnail location  gbif_info/note  \
# 0        Trametes     Polyporales          1     69.0             NaN
# 1        Trametes     Polyporales          0     60.0             NaN
# 2        Trametes     Polyporales          1     60.0             NaN
# 3   Schizophyllum      Agaricales          1     58.0             NaN
# 4         Russula      Russulales          1     53.0             NaN
#
#    gbif_info       Nom scientifique           Nom commun  \
# 0        NaN    Trametes versicolor  Tramète versicolore
# 1        NaN    Trametes versicolor  Tramète versicolore
# 2        NaN    Trametes versicolor  Tramète versicolore
# 3        NaN  Schizophyllum commune  Schizophylle commun
# 4        NaN      Russula virescens   Russule verdoyante
#
#                        Statut             Habitat typique
# 0  Non comestible (médicinal)                  Bois morts
# 1  Non comestible (médicinal)                  Bois morts
# 2  Non comestible (médicinal)                  Bois morts
# 3              Non comestible                  Bois morts
# 4                  Comestible  Forêts claires de feuillus
#
# [5 rows x 37 columns]

# %%
# apperçu des variables

display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20592 entries, 0 to 20591
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   image_lien                20592 non-null  object
#  1   image_id                  20592 non-null  int64
#  2   observation               20592 non-null  object
#  3   label                     20592 non-null  object
#  4   image_url                 20592 non-null  object
#  5   user                      20592 non-null  object
#  6   date                      20592 non-null  object
#  7   gbif_info/kingdom         20592 non-null  object
#  8   gbif_info/family          20592 non-null  object
#  9   gbif_info/speciesKey      20592 non-null  float64
#  10  gbif_info/rank            20592 non-null  object
#  11  gbif_info/phylum          20592 non-null  object
#  12  gbif_info/orderKey        20592 non-null  float64
#  13  gbif_info/species         20592 non-null  object
#  14  gbif_info/confidence      20592 non-null  float64
#  15  gbif_info/classKey        20592 non-null  float64
#  16  gbif_info/matchType       20592 non-null  object
#  17  gbif_info/familyKey       20592 non-null  float64
#  18  gbif_info/status          20592 non-null  object
#  19  gbif_info/usageKey        20592 non-null  float64
#  20  gbif_info/kingdomKey      20592 non-null  float64
#  21  gbif_info/genusKey        20592 non-null  float64
#  22  gbif_info/canonicalName   20592 non-null  object
#  23  gbif_info/phylumKey       20592 non-null  float64
#  24  gbif_info/class           20592 non-null  object
#  25  gbif_info/synonym         20592 non-null  bool
#  26  gbif_info/scientificName  20592 non-null  object
#  27  gbif_info/genus           20592 non-null  object
#  28  gbif_info/order           20592 non-null  object
#  29  thumbnail                 20592 non-null  int64
#  30  location                  20590 non-null  object
#  31  gbif_info/note            383 non-null    object
#  32  gbif_info                 0 non-null      float64
#  33  Nom scientifique          20592 non-null  object
#  34  Nom commun                20592 non-null  object
#  35  Statut                    20592 non-null  object
#  36  Habitat typique           20592 non-null  object
# dtypes: bool(1), float64(10), int64(2), object(24)
# memory usage: 5.7+ MB
# None

# %%
df.shape
# Out:
# (20592, 37)

# %%
valeurs_manquantes = pd.DataFrame(df.isna().sum(), columns=["nb_val_manquantes"])
valeurs_manquantes.loc[valeurs_manquantes["nb_val_manquantes"] != 0]
# Out:
#                 nb_val_manquantes
# location                        2
# gbif_info/note              20209
# gbif_info                   20592

# %%
# Analyse de la variable de confiance dans les labellisations "gbif_info/confidence"

sns.countplot(x=df["gbif_info/confidence"])

display(df["gbif_info/confidence"].describe())
# Out:
# count    20592.000000
# mean        97.735528
# std          0.444681
# min         94.000000
# 25%         97.000000
# 50%         98.000000
# 75%         98.000000
# max         98.000000
# Name: gbif_info/confidence, dtype: float64

# %%
cols = [
    "gbif_info/kingdom",
    "gbif_info/phylum",
    "gbif_info/class",
    "gbif_info/order",
    "gbif_info/family",
    "gbif_info/genus",
    "gbif_info/species",
    "Nom commun",
    "Statut",
    "Habitat typique",
]

# %%
df[cols].describe(include="object")
# Out:
#        gbif_info/kingdom gbif_info/phylum gbif_info/class gbif_info/order  \
# count              20592            20592           20592           20592
# unique                 1                1               1               7
# top                Fungi    Basidiomycota  Agaricomycetes      Agaricales
# freq               20592            20592           20592           11769
#
#        gbif_info/family gbif_info/genus gbif_info/species  \
# count             20592           20592             20592
# unique               16              20                30
# top         Amanitaceae         Amanita  Amanita muscaria
# freq               5347            5347              3581
#
#                  Nom commun      Statut                Habitat typique
# count                 20592       20592                          20592
# unique                   30          10                             25
# top     Amanite tue-mouches  Comestible  Forêts de bouleaux, conifères
# freq                   3581        7857                           3581

# %%
#### Ajout ####
analyse_espece = df.groupby("gbif_info/species")["gbif_info/species"].count()
analyse_espece = pd.DataFrame(analyse_espece.describe())
analyse_espece
# Out:
#        gbif_info/species
# count          30.000000
# mean          686.400000
# std           767.902948
# min            58.000000
# 25%           191.000000
# 50%           449.500000
# 75%           892.250000
# max          3581.000000

# %%
ordres = df["gbif_info/order"].value_counts()
plt.figure(figsize=(10, 5))
ax = sns.barplot(x=ordres.values, y=ordres.index, palette="viridis")
plt.title("Classement du top 30 Espèces France, par 'Order' (en nb d'observations)")
plt.xlabel("Nombre d'observations")
plt.ylabel("Ordres")

for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])

plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\2471047605.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=ordres.values, y=ordres.index, palette='viridis')

# %%
familles = df["gbif_info/family"].value_counts()
plt.figure(figsize=(10, 5))
ax = sns.barplot(x=familles.values, y=familles.index, palette="viridis")
plt.title("Classement du top 30 Espèces France, par 'Family' (en nb d'observations)")
plt.xlabel("Nombre d'observations")
plt.ylabel("Familles")

for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])

plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\1581028685.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=familles.values, y=familles.index, palette='viridis')

# %%
genres = df["gbif_info/genus"].value_counts()
plt.figure(figsize=(10, 5))
ax = sns.barplot(x=genres.values, y=genres.index, palette="viridis")
plt.title("Classement du top 30 Espèces France, par 'Genus' (en nb d'observations)")
plt.xlabel("Nombre d'observations")
plt.ylabel("Genres")


for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])

plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\3735532063.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=genres.values, y=genres.index, palette='viridis')

# %%
especes = df["gbif_info/species"].value_counts()
plt.figure(figsize=(12, 8))
ax = sns.barplot(x=especes.values, y=especes.index, palette="viridis")
plt.title("Classement du top 30 Espèces France par nb d'observations")
plt.xlabel("Nombre d'observations")
plt.ylabel("Espèces")

for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])

plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\63156974.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=especes.values, y=especes.index, palette='viridis')

# %%
noms_communs = df["Nom commun"].value_counts()
plt.figure(figsize=(12, 8))
ax = sns.barplot(x=noms_communs.values, y=noms_communs.index, palette="viridis")
plt.title("Classement du top 30 Espèces France (Noms Communs) par nb d'observations")
plt.xlabel("Nombre d'observations")
plt.ylabel("Noms communs Espèces")

for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])

plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\3266153353.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=noms_communs.values, y=noms_communs.index, palette='viridis')

# %%
habitats = df["Habitat typique"].value_counts()
plt.figure(figsize=(12, 8))
ax = sns.barplot(x=habitats.values, y=habitats.index, palette="viridis")
plt.title("Classement du top 30 Espèces France, par type d'habitat (en nb d'observations)")
plt.xlabel("Nombre d'observations")
plt.ylabel("Type d'habitat")

for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])

plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\3811668612.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=habitats.values, y=habitats.index, palette='viridis')

# %%
status = df["Statut"].value_counts()
plt.figure(figsize=(10, 5))
ax = sns.barplot(x=status.values, y=status.index, palette="viridis")
plt.title(
    "Classement du top 30 Espèces France, par Statut comestible / toxique (en nb d'observations)"
)
plt.xlabel("Nombre d'observations")
plt.ylabel("Statut")


for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])

plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17756\3878980542.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=status.values, y=status.index, palette='viridis')
